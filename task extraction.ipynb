# %%
import re
import nltk
import spacy
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from IPython.display import display
nltk.download('punkt')
nltk.download('stopwords')
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/parthabhang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/parthabhang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Function to Read I/P file
def read_text_file(file_path):
    try:
        with open(file_path, "r", encoding="utf-8") as file:
            text = file.read()
        return text
    except FileNotFoundError:
        print("Error: The file was not found.")
        return ""

# %%
# Function to Clean Text
def preprocess_text(text):
    text = re.sub(r'\s+', ' ', text)
    sentences = sent_tokenize(text)
    return sentences

# %%
# Function to POS for Verb Only
def pos_tagging(sentence):
    doc = nlp(sentence)
    verbs = [token.text for token in doc if token.pos_ == "VERB"]
    return verbs

# %%
# Function to Lemmatize Verb
def lemmatize_verb(verb):
    doc = nlp(verb)
    return doc[0].lemma_

# %%
# Function to Get only main verb
def extract_main_verb(sentence):
    doc = nlp(sentence)
    for token in doc:
        if token.pos_ == "VERB" or token.dep_ == "ROOT":  # Get main verb
            return lemmatize_verb(token.text)
    return "No verb found"

# %%
# Function to Identify Task
def identify_tasks(sentences):
    task_verbs = []
    for sentence in sentences:
        verb = extract_main_verb(sentence)
        if verb != "No verb found":
            task_verbs.append(verb)
    return task_verbs

# %%
# Function to Extract name
def extract_who_task(task_sentence):
    doc = nlp(task_sentence)
    for token in doc:
        if token.pos_ in ["PROPN", "PRON"]:  # Proper Noun or Pronoun
            return token.text
    return "Unknown"

# %%
# Function to Extract Deadline
def extract_deadline(task_sentence):
    doc = nlp(task_sentence)
    for ent in doc.ents:
        if ent.label_ in ["TIME", "DATE"]:
            return ent.text
    return "No deadline specified"

# %%
# Function for Categorization of task
def categorize_task(task_sentence):
    categories = {
        "Personal": ["wake", "sleep", "play", "workout", "exercise", "relax", "rest", "meditate", "travel", "go", "text", "call"],
        "Household": ["clean", "wash", "cook", "sweep", "mop", "laundry", "repair", "arrange", "fix", "organize"],
        "Shopping": ["buy", "purchase", "order", "shop", "pay", "pick", "collect", "return", "exchange"],
        "Work": ["review", "submit", "study", "meeting", "code", "complete", "write", "read", "analyze", "plan", "discuss", "present", "schedule", "design", "report"],
        "Appointments & Meetings": ["schedule", "attend", "reschedule", "organize", "cancel", "confirm", "set up", "book", "meet", "invite"],
        "Communication": ["call", "email", "text", "message", "reply", "respond", "chat", "discuss", "notify", "update", "report"],
        "Travel & Booking": ["book", "reserve", "cancel", "travel", "pack", "plan", "schedule", "check-in", "board", "arrange", "visit", "tour"],
        "Health & Fitness": ["exercise", "run", "walk", "jog", "gym", "yoga", "meditate", "train", "stretch", "workout", "hydrate"],
        "Finance & Payments": ["pay", "transfer", "deposit", "withdraw", "invest", "save", "budget", "buy", "sell", "donate", "fund"]
    }
    for category, keywords in categories.items():
        if any(keyword in task_sentence.lower() for keyword in keywords):
            return category
    return "Other"

# %%
# Load the file
file_path = "input.txt"
text = read_text_file(file_path)
# perform only if file found.
if text:
    sentences = preprocess_text(text)
    task_data = []
    for sentence in sentences:
        task = extract_main_verb(sentence)
        category = categorize_task(task)
        who = extract_who_task(sentence)
        deadline = extract_deadline(sentence)
        task_data.append({"Sentence": sentence, "Task": task, "Category": category, "Who": who, "Deadline": deadline})
    df = pd.DataFrame(task_data)
    # display the result in table
    display(df)

    # Save output in csv file.
    df.to_csv("task_output.csv", index=False)
    print("Output saved as task_output.csv")
# Out:
#                                              Sentence     Task  \
# 0   Alan wakes up early every day and goes for a m...     wake
# 1   He has to submit his project report by 5 PM to...     have
# 2   Neha should call the doctor to book an appoint...     call
# 3      Vikram needs to clean the garage this weekend.     need
# 4   Amit is required to buy groceries for the hous...  require
# 5   Priya must finish reading the research paper b...   finish
# 6   John has a dentist appointment at 4 PM, and he...     have
# 7   Anjali will travel to Mumbai for a conference ...   travel
# 8   Suresh has to pay the electricity bill before ...     have
# 9   Meera needs to schedule a meeting with the mar...     need
# 10    Raj is planning to invest in stocks next month.     plan
# 11  Sonia has to respond to the client's email by ...     have
# 12  Alan should book flight tickets for the family...     book
# 13   Arjun will attend the yoga class in the evening.   attend
# 14  Ravi needs to return the library books before ...     need
# 15  Kiran has to complete the software update for ...     have
# 16  Rohit should order a birthday gift for his fri...    order
# 17  Kavya is required to finalize the wedding arra...  require
# 18  Jay will join the gym from next Monday to impr...     join
# 19  Tina has to collect the package from the post ...     have
# 20  Sam needs to wash his car before going to the ...     need
# 21                   Alexander writes a book at 5 pm.    write
#
#                    Category        Who               Deadline
# 0                  Personal       Alan        early every day
# 1                     Other         He                   5 PM
# 2                  Personal    Unknown  No deadline specified
# 3                     Other     Vikram           this weekend
# 4                     Other    Unknown                   6 PM
# 5                     Other      Priya               tomorrow
# 6                     Other       John                   4 PM
# 7                  Personal     Mumbai            next Monday
# 8                     Other     Suresh                 Friday
# 9                     Other      Meera  No deadline specified
# 10                     Work    Unknown             next month
# 11                    Other      Sonia     the end of the day
# 12  Appointments & Meetings       Alan  No deadline specified
# 13  Appointments & Meetings      Arjun  No deadline specified
# 14                    Other    Unknown  No deadline specified
# 15                    Other      Kiran  No deadline specified
# 16                 Shopping      Rohit               Saturday
# 17                    Other      Kavya              next week
# 18                    Other        Jay            next Monday
# 19                    Other       Tina  No deadline specified
# 20                    Other        Sam  No deadline specified
# 21                     Work  Alexander                   5 pm
# Output saved as task_output.csv
