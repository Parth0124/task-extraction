# %%
import re
import nltk
import spacy
import pandas as pd
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords
from IPython.display import display
nltk.download('punkt')
nltk.download('stopwords')
nlp = spacy.load("en_core_web_sm")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/parthabhang/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/parthabhang/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Function to Read I/P file
def read_text_file(file_path):
    try:
        with open(file_path, "r", encoding="utf-8") as file:
            text = file.read()
        return text
    except FileNotFoundError:
        print("Error: The file was not found.")
        return ""

# %%
# Function to Clean Text
def preprocess_text(text):
    text = re.sub(r'\s+', ' ', text)
    sentences = sent_tokenize(text)
    return sentences

# %%
# Function to POS for Verb Only
def pos_tagging(sentence):
    doc = nlp(sentence)
    verbs = [token.text for token in doc if token.pos_ == "VERB"]
    return verbs

# %%
# Function to Lemmatize Verb
def lemmatize_verb(verb):
    doc = nlp(verb)
    return doc[0].lemma_

# %%
# Function to Get only main verb
def extract_main_verb(sentence):
    doc = nlp(sentence)
    for token in doc:
        if token.pos_ == "VERB" or token.dep_ == "ROOT":  # Get main verb
            return lemmatize_verb(token.text)
    return "No verb found"

# %%
# Function to Identify Task
def identify_tasks(sentences):
    task_verbs = []
    for sentence in sentences:
        verb = extract_main_verb(sentence)
        if verb != "No verb found":
            task_verbs.append(verb)
    return task_verbs

# %%
# Function to Extract name
def extract_who_task(task_sentence):
    doc = nlp(task_sentence)
    for token in doc:
        if token.pos_ in ["PROPN", "PRON"]:  # Proper Noun or Pronoun
            return token.text
    return "Unknown"

# %%
# Function to Extract Deadline
def extract_deadline(task_sentence):
    doc = nlp(task_sentence)
    for ent in doc.ents:
        if ent.label_ in ["TIME", "DATE"]:
            return ent.text
    return "No deadline specified"

# %%
# Function for Categorization of task
def categorize_task(task_sentence):
    categories = {
        "Personal": ["wake", "sleep", "play", "workout", "exercise", "relax", "rest", "meditate", "travel", "go", "text", "call"],
        "Household": ["clean", "wash", "cook", "sweep", "mop", "laundry", "repair", "arrange", "fix", "organize"],
        "Shopping": ["buy", "purchase", "order", "shop", "pay", "pick", "collect", "return", "exchange"],
        "Work": ["review", "submit", "study", "meeting", "code", "complete", "write", "read", "analyze", "plan", "discuss", "present", "schedule", "design", "report"],
        "Appointments & Meetings": ["schedule", "attend", "reschedule", "organize", "cancel", "confirm", "set up", "book", "meet", "invite"],
        "Communication": ["call", "email", "text", "message", "reply", "respond", "chat", "discuss", "notify", "update", "report"],
        "Travel & Booking": ["book", "reserve", "cancel", "travel", "pack", "plan", "schedule", "check-in", "board", "arrange", "visit", "tour"],
        "Health & Fitness": ["exercise", "run", "walk", "jog", "gym", "yoga", "meditate", "train", "stretch", "workout", "hydrate"],
        "Finance & Payments": ["pay", "transfer", "deposit", "withdraw", "invest", "save", "budget", "buy", "sell", "donate", "fund"]
    }
    for category, keywords in categories.items():
        if any(keyword in task_sentence.lower() for keyword in keywords):
            return category
    return "Other"

# %%
# Load the file
file_path = "input.txt"
text = read_text_file(file_path)
# perform only if file found.
if text:
    sentences = preprocess_text(text)
    task_data = []
    for sentence in sentences:
        task = extract_main_verb(sentence)
        category = categorize_task(task)
        who = extract_who_task(sentence)
        deadline = extract_deadline(sentence)
        task_data.append({"Sentence": sentence, "Task": task, "Category": category, "Who": who, "Deadline": deadline})
    df = pd.DataFrame(task_data)
    # display the result in table
    display(df)

    # Save output in csv file.
    df.to_csv("task_output.csv", index=False)
    print("Output saved as task_output.csv")
# Out:
#                                              Sentence      Task  \
# 0   Sarah must pick up her prescription from the p...      pick
# 1   Michael must submit his tax documents before t...    submit
# 2   Emma must prepare the presentation for tomorro...   prepare
# 3   William goes swimming every Thursday morning a...        go
# 4   Charlotte should call her grandmother this eve...      call
# 5   James will start his new job at the tech compa...     start
# 6   Oliver must fix the leaking faucet in the kitc...       fix
# 7   Isabella must renew her driver's license befor...     renew
# 8   Thomas must finish painting the living room wa...    finish
# 9   Elizabeth should schedule a haircut appointmen...  schedule
# 10  Henry will attend the concert with friends on ...    attend
# 11    Lucy must return the borrowed dress to Jessica.    return
# 12   George must mow the lawn before the rain starts.       mow
# 13  Carol must complete the online certification c...  complete
# 14  Benjamin should pick up his suit from the dry ...      pick
# 15  Frank will host a dinner party this Saturday e...      host
# 16  Matthew must update his resume before applying...    update
# 17  Edward must charge his electric car before the...    charge
# 18  Claire should water the plants before leaving ...     water
# 19  Robert will teach piano lessons every Wednesda...     teach
# 20  Alice must backup her computer files before fo...    backup
# 21  Daniel must collect his watch from the repair ...   collect
# 22  Victoria must finish knitting the sweater befo...    finish
# 23  Christopher should order new contact lenses th...     order
# 24  Margaret will attend her cousin's wedding next...    attend
# 25        Andrew must repair his bicycle's flat tire.    repair
# 26  Eleanor must submit her research proposal by F...    submit
# 27  Patrick must clean out his email inbox before ...     clean
# 28  Rose should buy new running shoes for the mara...       buy
# 29    Timothy will start guitar lessons next Tuesday.     start
# 30        Catherine must organize her digital photos.  organize
# 31      Jonathan must replace the broken window pane.   replace
# 32  Sophia must prepare for her driving test next ...   prepare
# 33  Peter should update his passport before it exp...    update
# 34    Hannah will begin her art classes this weekend.     begin
# 35  David must schedule a dental cleaning appointm...  schedule
# 36  Rachel must finish writing her novel's final c...    finish
# 37  Philip must repair the garden fence before spr...    repair
# 38  Martha should order groceries for the holiday ...     order
# 39   Arthur will plant new flowers in the garden bed.     plant
# 40               Emily must renew her gym membership.     renew
# 41  Samuel must collect his new glasses from the o...   collect
# 42  Robin must finish the homework before watching...    finish
# 43  Charles should book tickets for the theater show.      book
#
#                    Category          Who                   Deadline
# 0                  Shopping        Sarah                       3 PM
# 1                      Work      Michael               next Tuesday
# 2                     Other         Emma                   tomorrow
# 3                  Personal      William                    morning
# 4                  Personal    Charlotte               this evening
# 5                     Other        James                 next month
# 6                 Household       Oliver               this weekend
# 7                     Other     Isabella      No deadline specified
# 8                     Other       Thomas                     Sunday
# 9                      Work    Elizabeth                  next week
# 10  Appointments & Meetings        Henry               Friday night
# 11                 Shopping         Lucy      No deadline specified
# 12                    Other       George      No deadline specified
# 13                     Work        Carol                  month-end
# 14                 Shopping     Benjamin      No deadline specified
# 15                    Other        Frank              this Saturday
# 16            Communication      Matthew      No deadline specified
# 17                    Other       Edward      No deadline specified
# 18                    Other       Claire      No deadline specified
# 19                    Other       Robert                  Wednesday
# 20                    Other        Alice      No deadline specified
# 21                 Shopping       Daniel      No deadline specified
# 22                    Other     Victoria  the sweater before winter
# 23                 Shopping  Christopher                  this week
# 24  Appointments & Meetings     Margaret                 next month
# 25                Household       Andrew      No deadline specified
# 26                     Work          her                     Friday
# 27                Household      Patrick                the weekend
# 28                 Shopping         Rose      No deadline specified
# 29                    Other      Timothy               next Tuesday
# 30                Household    Catherine      No deadline specified
# 31                    Other     Jonathan      No deadline specified
# 32                    Other       Sophia                  next week
# 33            Communication        Peter      No deadline specified
# 34                    Other       Hannah               this weekend
# 35                     Work        David      No deadline specified
# 36                    Other       Rachel      No deadline specified
# 37                Household       Philip      No deadline specified
# 38                 Shopping       Martha      No deadline specified
# 39                     Work       Arthur      No deadline specified
# 40                    Other        Emily      No deadline specified
# 41                 Shopping       Samuel      No deadline specified
# 42                    Other        Robin      No deadline specified
# 43  Appointments & Meetings      Charles      No deadline specified
# Output saved as task_output.csv
#                                                                Sentence     Task                Category         Who                  Deadline
#          Sarah must pick up her prescription from the pharmacy by 3 PM.     pick                Shopping       Sarah                      3 PM
# Michael must submit his tax documents before the deadline next Tuesday.   submit                    Work     Michael              next Tuesday
#       Emma must prepare the presentation for tomorrow's client meeting.  prepare                   Other        Emma                  tomorrow
#         William goes swimming every Thursday morning at the local pool.       go                Personal     William                   morning
#                     Charlotte should call her grandmother this evening.     call                Personal   Charlotte              this evening
#            James will start his new job at the tech company next month.    start                   Other       James                next month
#         Oliver must fix the leaking faucet in the kitchen this weekend.      fix               Household      Oliver              this weekend
#             Isabella must renew her driver's license before it expires.    renew                   Other    Isabella     No deadline specified
#            Thomas must finish painting the living room walls by Sunday.   finish                   Other      Thomas                    Sunday
#          Elizabeth should schedule a haircut appointment for next week. schedule                    Work   Elizabeth                 next week
#             Henry will attend the concert with friends on Friday night.   attend Appointments & Meetings       Henry              Friday night
#                         Lucy must return the borrowed dress to Jessica.   return                Shopping        Lucy     No deadline specified
#                        George must mow the lawn before the rain starts.      mow                   Other      George     No deadline specified
#       Carol must complete the online certification course by month-end. complete                    Work       Carol                 month-end
#                 Benjamin should pick up his suit from the dry cleaners.     pick                Shopping    Benjamin     No deadline specified
#                   Frank will host a dinner party this Saturday evening.     host                   Other       Frank             this Saturday
#                Matthew must update his resume before applying for jobs.   update           Communication     Matthew     No deadline specified
#               Edward must charge his electric car before the road trip.   charge                   Other      Edward     No deadline specified
#             Claire should water the plants before leaving for vacation.    water                   Other      Claire     No deadline specified
#              Robert will teach piano lessons every Wednesday afternoon.    teach                   Other      Robert                 Wednesday
#                 Alice must backup her computer files before formatting.   backup                   Other       Alice     No deadline specified
#                     Daniel must collect his watch from the repair shop.  collect                Shopping      Daniel     No deadline specified
#                Victoria must finish knitting the sweater before winter.   finish                   Other    Victoria the sweater before winter
#                  Christopher should order new contact lenses this week.    order                Shopping Christopher                 this week
#                   Margaret will attend her cousin's wedding next month.   attend Appointments & Meetings    Margaret                next month
#                             Andrew must repair his bicycle's flat tire.   repair               Household      Andrew     No deadline specified
#                    Eleanor must submit her research proposal by Friday.   submit                    Work         her                    Friday
#              Patrick must clean out his email inbox before the weekend.    clean               Household     Patrick               the weekend
#                     Rose should buy new running shoes for the marathon.      buy                Shopping        Rose     No deadline specified
#                         Timothy will start guitar lessons next Tuesday.    start                   Other     Timothy              next Tuesday
#                             Catherine must organize her digital photos. organize               Household   Catherine     No deadline specified
#                           Jonathan must replace the broken window pane.  replace                   Other    Jonathan     No deadline specified
#                     Sophia must prepare for her driving test next week.  prepare                   Other      Sophia                 next week
#                     Peter should update his passport before it expires.   update           Communication       Peter     No deadline specified
#                         Hannah will begin her art classes this weekend.    begin                   Other      Hannah              this weekend
#                      David must schedule a dental cleaning appointment. schedule                    Work       David     No deadline specified
#                   Rachel must finish writing her novel's final chapter.   finish                   Other      Rachel     No deadline specified
#                      Philip must repair the garden fence before spring.   repair               Household      Philip     No deadline specified
#                   Martha should order groceries for the holiday dinner.    order                Shopping      Martha     No deadline specified
#                        Arthur will plant new flowers in the garden bed.    plant                    Work      Arthur     No deadline specified
#                                    Emily must renew her gym membership.    renew                   Other       Emily     No deadline specified
#                  Samuel must collect his new glasses from the optician.  collect                Shopping      Samuel     No deadline specified
#                      Robin must finish the homework before watching TV.   finish                   Other       Robin     No deadline specified
#                       Charles should book tickets for the theater show.     book Appointments & Meetings     Charles     No deadline specified
